# %% [markdown]
# # Importing Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Dataset

# %%
# Importing 'ords_prods_merge' dataset.
ords_prods_merge= pd.read_csv(r'C:\users\Ali Hassan\Documents\MM-2020 Instacart Basket Analysis\Data\Prepared data\ords_prods_merge.csv', index_col=0)

# %% [markdown]
# # Step 1a: Create 'price_label' column.

# %%
# Creating a subset of dataframe.
df= ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
# Define a function.
def price_label(row):
    
    if row['prices'] <=5:
     return 'Low-range product'
    elif (row['prices'] >5) and (row['prices'] <=15):
     return 'Mid-range product'
    elif row['prices'] > 15:
     return 'High_range'
    else: return 'Not enough data'

# %%
# apply the function.
df['price_range']= df.apply(price_label, axis=1)
# Out:
# C:\Users\ALI HASSAN\AppData\Local\Temp\ipykernel_16952\3128605150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range']= df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High_range            12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
# Use loc method on entire ords_prods_merge dataframe to apply price_range function.
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_range_loc'] = "Mid range product"

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid range product     2093575
# Low range product      968703
# High range product      39014
# Name: count, dtype: int64

# %% [markdown]
# # Step 1b: Create 'Busiest day' column.

# %%
# Find frequency of orders_day_of_week.
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    588695
# 1    534032
# 6    431920
# 5    408235
# 2    404460
# 3    369786
# 4    364164
# Name: count, dtype: int64

# %%
# Use For_loop method to check.
result = []

for value in ords_prods_merge["orders_day_of_week"]:
 if value == 0:
  result.append("Busiest day")
 elif value == 4:
  result.append("Least busy")
 else:
  result.append("Regular busy")

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
# ...

# %%
# Create a new column 'Busiest day' in ords_prods_merge data frame.
ords_prods_merge['Busiest_day'] = result

# %%
ords_prods_merge['Busiest_day'].value_counts(dropna = False)
# Out:
# Busiest_day
# Regular busy    2148433
# Busiest day      588695
# Least busy       364164
# Name: count, dtype: int64

# %% [markdown]
# # Step 2: Change the 'Busiest day' column to 'Busiest days' to identify orders_day_of_week as "Busiest days', 'Slowest days' and 'regular days'.

# %%
# Create column 'Busiest days' from 'orders_day_of_week'.
result_2 = []

for value in ords_prods_merge["orders_day_of_week"]:
    if value == 0 or value == 1:
     result_2.append("Busiest days")
    elif value == 3 or value == 4:
     result_2.append("Slowest days")
    else:
     result_2.append("Regularly busy")

# %%
result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %% [markdown]
# # Step 3: Check value of new column 'Busiest days'.

# %%
# Create new column 'Busiest days' in ords_prods_merge to view results in context.
ords_prods_merge['Busiest days'] = result_2

# %%
ords_prods_merge['Busiest days'].value_counts(dropna = False)
# Out:
# Busiest days
# Regularly busy    1244615
# Busiest days      1122727
# Slowest days       733950
# Name: count, dtype: int64

# %%
# Checking output of ords_prods_merge with new column "Busiest days".
ords_prods_merge.head()
# Out:
#           user_id  order_number  orders_day_of_week  order_hour_of_day  \
# order_id
# 2539329         1             1                   2                  8
# 2539329         1             1                   2                  8
# 2539329         1             1                   2                  8
# 2539329         1             1                   2                  8
# 2539329         1             1                   2                  8
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# order_id
# 2539329                      NaN         196                  1          0
# 2539329                      NaN       14084                  2          0
# 2539329                      NaN       12427                  3          0
# 2539329                      NaN       26088                  4          0
# 2539329                      NaN       26405                  5          0
#
# ...

# %% [markdown]
# The total value counts for ords_prods_merge dataframe is equal to the total sum of all groupings( i.e "Regularly busy", "Busiest days", "Slowest days"). In addition, the listed sum for each label match the sum totals for the qualifying days of the week (e.g Total "Busiest days" = 11864412, which matches orders_day_of _week 0+1, or6204182 + 5660230).

# %% [markdown]
# # Step 4: Create new column "busoest_period_of_day" to identify time periods "Most orders", "Average orders" and "Fewest orders".

# %%
# Check value counts in "order_hour_of_day" column.
ords_prods_merge['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    262737
# 11    261838
# 14    254949
# 13    253906
# 12    253620
# 15    253500
# 16    240918
# 9     234795
# 17    203550
# 8     164173
# 18    158412
# 19    121966
# 20     93633
# 7      87294
# 21     77098
# 22     61164
# 23     37235
# 6      27315
# 0      18734
# 1      10291
# 5       8425
# 2       5938
# 4       5432
# 3       4369
# Name: count, dtype: int64

# %%
# Create For-loop if statement.

result_3 =[]

for value in ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        result_3.append("Most orders")
    elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
        result_3.append("Fewest orders")
    else:
        result_3.append("Average orders")

# %%
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
# ...

# %%
# Create new column "busiest_period_of_day" in ords_prods_merge.
ords_prods_merge['busiest_period_of_day'] = result_3

# %% [markdown]
# # Step 5: Print frequency of 'busiest_period_of_day'.

# %%
ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       2016263
# Average orders     967290
# Fewest orders      117739
# Name: count, dtype: int64

# %% [markdown]
# # Export data as pickle file.

# %%
ords_prods_merge.to_pickle(r'C:\users\Ali Hassan\Documents\MM-2020 Instacart Basket Analysis\Data\Prepared data\orders_products_merged_derived.pkl')
