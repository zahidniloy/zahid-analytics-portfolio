# %% [markdown]
# # Importing Libraries

# %%
# importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing data

# %%
df= pd.read_csv(r'C:\users\Ali Hassan\Documents\MM-2020 Instacart Basket Analysis\Data\Original data\orders.csv', index_col =False)

# %%
# Define the project folder path
path= r'C:\users\Ali Hassan\Documents\MM-2020 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\users\\Ali Hassan\\Documents\\MM-2020 Instacart Basket Analysis'

# %%
#Define the path to data file
df= pd.read_csv(os.path.join(path, 'data','original data','orders.csv'), nrows=1000)

# %%
#Define the columns to include (excluding 'eval_set')
vars_list= [ 'order_id','user_id','order_number','order_dow','order_hour_of_day','days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
df= pd.read_csv(os.path.join(path,'data','original data','orders.csv'), usecols = vars_list)

# %%
#Display the first five rows of 'orders.csv' dataset
df.head(5)
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
#Define the path to 'product_csv' file
df_prods= pd.read_csv(os.path.join(path, 'data','original data','products.csv'), nrows=1000)

# %%
#Display the firts 20 rows of 'products_csv' data set.
df_prods.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 0            1                         Chocolate Sandwich Cookies        61
# 1            2                                   All-Seasons Salt       104
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 3            4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4            5                          Green Chile Anytime Sauce         5
# 5            6                                       Dry Nose Oil        11
# 6            7                     Pure Coconut Water With Orange        98
# 7            8                  Cut Russet Potatoes Steam N' Mash       116
# 8            9                  Light Strawberry Blueberry Yogurt       120
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# ...

# %%
#Display the last 35 rows of 'products_csv' dataset.
df_prods.tail(35)
# Out:
#      product_id                                      product_name  aisle_id  \
# 965         965             Maxtra Cartridge Water Filter Refills        87
# 966         966                                   Pear Hard Cider        27
# 967         967   Gluten Free Soft & Chewy Snicker Doodle Cookies         8
# 968         968                      Zipper Bags Sandwich - 50 CT        85
# 969         969                                 Petite Green Peas       116
# 970         970              Salmon and Tuna Formula Dry Cat Food        41
# 971         971                       Chicken Alfredo with Rotini        38
# 972         972                               Linguine No 7 Pasta       131
# 973         973                               8 X 6 Cutting Board        10
# 974         974              Organic 54% Cocoa Dark Chocolate Bar        45
# 975         975            Creamy Vanilla Soy Milk Frozen Dessert        37
# ...

# %%
#Display the column names in 'product_csv' dataset.
df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
#Display the number of rows and column in "product_csv' dataset.
df_prods.shape
# Out:
# (1000, 5)

# %%
# Find the maximum value of the 'aisle_id' in df_pandas.
max_aisle_id= df_prods['aisle_id']. max()

# %%
print("Maximum value of aisle_id:",max_aisle_id)
# Out:
# Maximum value of aisle_id: 134

# %%
# Check the data type of the 'department_id' in df_prods.
dept_id_type= df_prods['department_id'].dtype

# %%
print("data type of deppartment_id:",dept_id_type)
# Out:
# data type of deppartment_id: int64

# %% [markdown]
# # Answers
# 1. The maximum value of 'aisle_id' in df_pandas is 134.
# 2. The data type of 'department_id' in df_prods is 'int64'.
